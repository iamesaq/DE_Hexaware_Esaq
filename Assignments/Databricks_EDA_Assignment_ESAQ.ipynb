# %% [markdown]
# # EDA Visualizing Data in Databricks

# %% [markdown]
# #### by Esaq

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import avg, sum, min, max, count

spark = SparkSession.builder.appName("EDA_Students").getOrCreate()

# %%
df = spark.read.option("header", True).option("inferSchema", True).csv("/FileStore/tables/StudentsPerformance.csv")
df.show(5)
# Out:
# +------+--------------+---------------------------+------------+-----------------------+----------+-------------+-------------+
# |gender|race/ethnicity|parental level of education|       lunch|test preparation course|math score|reading score|writing score|
# +------+--------------+---------------------------+------------+-----------------------+----------+-------------+-------------+
# |female|       group B|          bachelor's degree|    standard|                   none|        72|           72|           74|
# |female|       group C|               some college|    standard|              completed|        69|           90|           88|
# |female|       group B|            master's degree|    standard|                   none|        90|           95|           93|
# |  male|       group A|         associate's degree|free/reduced|                   none|        47|           57|           44|
# |  male|       group C|               some college|    standard|                   none|        76|           78|           75|
# +------+--------------+---------------------------+------------+-----------------------+----------+-------------+-------------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- gender: string (nullable = true)
#  |-- race/ethnicity: string (nullable = true)
#  |-- parental level of education: string (nullable = true)
#  |-- lunch: string (nullable = true)
#  |-- test preparation course: string (nullable = true)
#  |-- math score: integer (nullable = true)
#  |-- reading score: integer (nullable = true)
#  |-- writing score: integer (nullable = true)

# %% [markdown]
# ### Gender-wise Student Count

# %%
gender_df = df.groupBy("gender") \
              .count() \
              .orderBy("count", ascending=False)

display(gender_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gender</th><th>count</th></tr></thead><tbody><tr><td>female</td><td>518</td></tr><tr><td>male</td><td>482</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Average Scores by Gender

# %%
avg_scores_gender = df.groupBy("gender") \
    .agg(
        avg("math score").alias("avg_math"),
        avg("reading score").alias("avg_reading"),
        avg("writing score").alias("avg_writing")
    )

display(avg_scores_gender)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gender</th><th>avg_math</th><th>avg_reading</th><th>avg_writing</th></tr></thead><tbody><tr><td>female</td><td>63.633204633204635</td><td>72.60810810810811</td><td>72.46718146718146</td></tr><tr><td>male</td><td>68.72821576763485</td><td>65.47302904564316</td><td>63.31120331950208</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Distribution of Math Scores

# %%
math_scores = df.select("math score")
display(math_scores)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>math score</th></tr></thead><tbody><tr><td>72</td></tr><tr><td>69</td></tr><tr><td>90</td></tr><tr><td>47</td></tr><tr><td>76</td></tr><tr><td>71</td></tr><tr><td>88</td></tr><tr><td>40</td></tr><tr><td>64</td></tr><tr><td>38</td></tr><tr><td>58</td></tr><tr><td>40</td></tr><tr><td>65</td></tr><tr><td>78</td></tr><tr><td>50</td></tr><tr><td>69</td></tr><tr><td>88</td></tr><tr><td>18</td></tr><tr><td>46</td></tr><tr><td>54</td></tr><tr><td>66</td></tr><tr><td>65</td></tr><tr><td>44</td></tr><tr><td>69</td></tr><tr><td>74</td></tr><tr><td>73</td></tr><tr><td>69</td></tr><tr><td>67</td></tr><tr><td>70</td></tr><tr><td>62</td></tr><tr><td>69</td></tr><tr><td>63</td></tr><tr><td>56</td></tr><tr><td>40</td></tr><tr><td>97</td></tr><tr><td>81</td></tr><tr><td>74</td></tr><tr><td>50</td></tr><tr><td>75</td></tr><tr><td>57</td></tr><tr><td>55</td></tr><tr><td>58</td></tr><tr><td>53</td></tr><tr><td>59</td></tr><tr><td>50</td></tr><tr><td>65</td></tr><tr><td>55</td></tr><tr><td>66</td></tr><tr><td>57</td></tr
td>49</td></tr><tr><td>44</td><td>41</td></tr><tr><td>30</td><td>26</td></tr><tr><td>80</td><td>78</td></tr><tr><td>61</td><td>74</td></tr><tr><td>62</td><td>68</td></tr><tr><td>47</td><td>49</td></tr><tr><td>49</td><td>45</td></tr><tr><td>50</td><td>47</td></tr><tr><td>72</td><td>64</td></tr><tr><td>42</td><td>39</td></tr><tr><td>73</td><td>80</td></tr><tr><td>76</td><td>83</td></tr><tr><td>71</td><td>71</td></tr><tr><td>58</td><td>70</td></tr><tr><td>73</td><td>86</td></tr><tr><td>65</td><td>72</td></tr><tr><td>27</td><td>34</td></tr><tr><td>71</td><td>79</td></tr><tr><td>43</td><td>45</td></tr><tr><td>79</td><td>86</td></tr><tr><td>78</td><td>81</td></tr><tr><td>65</td><td>66</td></tr><tr><td>63</td><td>72</td></tr><tr><td>58</td><td>67</td></tr><tr><td>65</td><td>67</td></tr><tr><td>79</td><td>67</td></tr><tr><td>68</td><td>74</td></tr><tr><td>85</td><td>91</td></tr><tr><td>60</td><td>44</td></tr><tr><td>98</td><td>86</td></tr><tr><td>58</td><td>67</td></tr><tr><td>87</td><td>100</td></tr><tr><td>66</td><td>63</td></tr><tr><td>52</td><td>76</td></tr><tr><td>70</td><td>64</td></tr><tr><td>77</td><td>89</td></tr><tr><td>62</td><td>55</td></tr><tr><td>54</td><td>53</td></tr><tr><td>51</td><td>58</td></tr><tr><td>99</td><td>100</td></tr><tr><td>84</td><td>77</td></tr><tr><td>75</td><td>85</td></tr><tr><td>78</td><td>82</td></tr><tr><td>51</td><td>63</td></tr><tr><td>55</td><td>69</td></tr><tr><td>79</td><td>92</td></tr><tr><td>91</td><td>89</td></tr><tr><td>88</td><td>93</td></tr><tr><td>63 ...
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Average Math Score by Race/Ethnicity

# %%
race_math = df.groupBy("race/ethnicity") \
              .agg(avg("math score").alias("avg_math")) \
              .orderBy("race/ethnicity")

display(race_math)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>race/ethnicity</th><th>avg_math</th></tr></thead><tbody><tr><td>group A</td><td>61.62921348314607</td></tr><tr><td>group B</td><td>63.45263157894737</td></tr><tr><td>group C</td><td>64.46394984326018</td></tr><tr><td>group D</td><td>67.36259541984732</td></tr><tr><td>group E</td><td>73.82142857142857</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Correlation Between Scores

# %%
scores_df = df.select("math score", "reading score", "writing score")

scores_pd = scores_df.toPandas()

import pandas as pd
corr_df = pd.DataFrame(scores_pd.corr())

spark_corr_df = spark.createDataFrame(corr_df.stack().reset_index())
spark_corr_df = spark_corr_df.withColumnRenamed("level_0", "score1") \
                             .withColumnRenamed("level_1", "score2") \
                             .withColumnRenamed("0", "correlation")

display(spark_corr_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>score1</th><th>score2</th><th>correlation</th></tr></thead><tbody><tr><td>math score</td><td>math score</td><td>1.0</td></tr><tr><td>math score</td><td>reading score</td><td>0.8175796636720539</td></tr><tr><td>math score</td><td>writing score</td><td>0.8026420459498075</td></tr><tr><td>reading score</td><td>math score</td><td>0.8175796636720539</td></tr><tr><td>reading score</td><td>reading score</td><td>1.0</td></tr><tr><td>reading score</td><td>writing score</td><td>0.9545980771462476</td></tr><tr><td>writing score</td><td>math score</td><td>0.8026420459498075</td></tr><tr><td>writing score</td><td>reading score</td><td>0.9545980771462476</td></tr><tr><td>writing score</td><td>writing score</td><td>1.0</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ![image.png](attachment:image.png)
